# %%
import wandb

# %%
ghgjh
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-14a31e6dbe66> in <cell line: 1>()
# ----> 1 ghgjh
#
# NameError: name 'ghgjh' is not defined
